# %% [markdown]
# <img src="Logo.png" width="100" align="left"/>
#
# # <center> Unit 3 Project </center>
# #  <center> Fourth section : Conclusion </center>
#
#
# In this notebook you will be comparing the results of the two methods we used on the created testset. That is said: you will compare the results to the clustering with the results of the classification on the same test test and provide insights and explanation about the observed behaviour.

# %% [markdown]
# For this final task you will need to :
# 1. Load the testset data that you created all along this project
# 2. For each cluster provide percentages about each actual/ predicted class contained with this cluster. Eg : cluster N°2 : is made of ( 50% class 2 and 50% class 3 ) from actual labels and ( 40 % predicted class 2 and 40% predicted class 3 + 20% predicted class 1)
# The above is just an example and is far away from the actual situation.
#
# 3. Explain the behaviour and provide isights about it

# %% [markdown]
# ## 1.  Load the data:

# %%
import pandas as pd

# %%
# To-Do : load the test summary data 
df = pd.read_csv('test_summary.csv')

# %%
df.head()
# Out:
#    Unnamed: 0   ID  Category  Age  Sex   ALB   ALP   ALT   AST  BIL    CHE  \
# 0          49   50         0   36    1  47.8  89.0  48.5  38.4  8.6   8.26
# 1         496  497         0   56    0  45.1  79.1  39.0  30.5  5.2   6.47
# 2         211  212         0   51    1  45.9  66.7  31.8  28.1  9.0  10.08
# 3         249  250         0   55    1  44.7  71.6  22.9  22.1  5.5   6.82
# 4         142  143         0   45    1  43.2  68.2  27.8  42.3  6.6  10.93
#
#    CHOL   CREA    GGT  PROT  cluster  Predicted_class
# 0  5.62   96.0   21.9  76.2        3                0
# 1  5.10   64.0  145.3  66.7        4                0
# 2  5.61   85.0   36.2  73.0        3                0
# 3  4.61  105.0   59.2  72.7        4                0
# 4  6.61  105.0   27.2  74.5        3                0

# %% [markdown]
# ## 2. Analysis:

# %%
# To-Do create a summary about each cluster : 
# percentages of each target (actual Category) within each cluster 
# + Percentages of each predicted class within the cluster 
# results should be something like : 
# For clusterk : {'true_class0_percetage': 0.0,
#                 'true_class1_percetage': 0.0,
#                  'true_class2_percetage': 0.0,
#                   'true_class3_percetage': 0.0,
#                   'true_class4_percetage': 0.0,
#                   'predicted_class0_percetage': 0.0,
#                   'predicted_class1_percetage': 0.0,
#                   'predicted_class2_percetage': 0.0,
#                   'predicted_class3_percetage': 0.0,
#                    'predicted_class4_percetage': 0.0}

true_classes = df['Category'].unique()
predicted_classes = df['Predicted_class'].unique()

# Initialize a dictionary to store the summary for each cluster
cluster_summary = {}

# Loop through each cluster and calculate percentages
for cluster in df['cluster'].unique():
    cluster_data = df[df['cluster'] == cluster]
    
    # Calculate the percentage of each true class within this cluster
    true_class_percentages = {f'true_class{cls}_percentage': (cluster_data['Category'] == cls).mean() * 100 for cls in true_classes}
    
    # Calculate the percentage of each predicted class within this cluster
    predicted_class_percentages = {f'predicted_class{cls}_percentage': (cluster_data['Predicted_class'] == cls).mean() * 100 for cls in predicted_classes}
    
    # Combine both true and predicted class percentages
    cluster_summary[cluster] = {**true_class_percentages, **predicted_class_percentages}

# Print the summary for each cluster
for cluster, summary in cluster_summary.items():
    print(f"Cluster {cluster}:")
    for key, value in summary.items():
        print(f"{key}: {value}%\n")
# Out:
# Cluster 3:
# true_class0_percentage: 98.88888888888889%
#
# true_class2_percentage: 1.1111111111111112%
#
# true_class4_percentage: 0.0%
#
# true_class1_percentage: 0.0%
#
# true_class3_percentage: 0.0%
#
# predicted_class0_percentage: 98.88888888888889%
#
# predicted_class4_percentage: 0.0%
#
# predicted_class2_percentage: 1.1111111111111112%
#
# predicted_class3_percentage: 0.0%
#
# predicted_class1_percentage: 0.0%
#
# Cluster 4:
# true_class0_percentage: 76.0%
#
# true_class2_percentage: 4.0%
#
# true_class4_percentage: 4.0%
#
# true_class1_percentage: 8.0%
#
# true_class3_percentage: 8.0%
#
# predicted_class0_percentage: 76.0%
#
# predicted_class4_percentage: 4.0%
#
# predicted_class2_percentage: 4.0%
#
# predicted_class3_percentage: 12.0%
#
# predicted_class1_percentage: 4.0%
#
# Cluster 2:
# true_class0_percentage: 0.0%
#
# true_class2_percentage: 100.0%
#
# true_class4_percentage: 0.0%
#
# true_class1_percentage: 0.0%
#
# true_class3_percentage: 0.0%
#
# predicted_class0_percentage: 0.0%
#
# predicted_class4_percentage: 100.0%
#
# predicted_class2_percentage: 0.0%
#
# predicted_class3_percentage: 0.0%
#
# predicted_class1_percentage: 0.0%
#
# Cluster 0:
# true_class0_percentage: 0.0%
#
# true_class2_percentage: 0.0%
#
# true_class4_percentage: 100.0%
#
# true_class1_percentage: 0.0%
#
# true_class3_percentage: 0.0%
#
# predicted_class0_percentage: 0.0%
#
# predicted_class4_percentage: 100.0%
#
# predicted_class2_percentage: 0.0%
#
# predicted_class3_percentage: 0.0%
#
# predicted_class1_percentage: 0.0%
#
# Cluster 1:
# true_class0_percentage: 0.0%
#
# true_class2_percentage: 20.0%
#
# true_class4_percentage: 80.0%
#
# true_class1_percentage: 0.0%
#
# true_class3_percentage: 0.0%
#
# predicted_class0_percentage: 0.0%
#
# predicted_class4_percentage: 80.0%
#
# predicted_class2_percentage: 20.0%
#
# predicted_class3_percentage: 0.0%
#
# predicted_class1_percentage: 0.0%

# %% [markdown]
# ## 3. Explanations and insights :

# %% [markdown]
# As can be seen from the result, the spread of the predicted and true class percentages match - which indicates that the model has perfomed well and correctly predicted the class distribution.

# %% [markdown]
# ## 4. Conclusion:
#
# Explain your findings and provide reasons for the behaviour.

# %% [markdown]
# As this is a small dataset it is unsurprising that initially overfitting was encountered. By doing a grid search, i was able to investigate the best hyper parameters to be used.
